# %% [markdown]
# # 说明文档

# %% [markdown]
# | 函数     | 代号    |
# |----------|---------|
# | 拆分列表 | list_cf |
# | 拆分函数 | fun_cf  |

# %% [markdown]
# ```json
# {
#     "起始符":"2",
#     "命令标识":"1",
#     "应答标识":"1",
#     "唯一识别码":"17",
#     "数据单元加密方式":"1",
#     "数据单元长度":"2",
#     "数据单元":{
#         "车辆登入01":{
#             "数据采集时间":"6",
#             "登入流水号":"2",
#             "ICCID":"20",
#             "可充电储能子系统数n":"1",
#             "可充电储能系统编码长度m":"1",
#             "可充电储能系统编码":"n*m"
#         },
#         "信息上报":{
#             "数据采集时间":"6",
#             "整车数据":{
#                 "车辆状态":"1",
#                 "充电状态":"1",
#                 "运行模式":"1",
#                 "车速":"2,",
#                 "累计里程":" 4",
#                 "总电压":"2,",
#                 "总电流":" 2",
#                 "SOC":"1",
#                 "DC-DC状态":"1",
#                 "挡位":"1",
#                 "绝缘电阻":"2",
#                 "加速踏板行程值":"1",
#                 "制动踏板状态":"1"
#             },
#             "驱动电机数据":{
#                 "驱动电机个数":"1",
#                 "驱动电机总成信息列表":{
#                     "1":{
#                         "驱动电机状态":"1",
#                         "驱动电机控制器温度":"1",
#                         "驱动电机转速":"2",
#                         "驱动电机转矩":"2",
#                         "驱动电机温度":"1",
#                         "电机控制器输入电压":"2",
#                         "电机控制器直流母线电流":"2",
#                     },
#                     "2":{}
#                 }
#             },
#             "燃料电池数据":{
#                 "燃料电池电压":"",
#                 "燃料电池电流":"",
#                 "燃料消耗率":"",
#                 "燃料电池温度探针总数":"",
#                 "探针温度值":"",
#                 "氢系统中最高温度":"",
#                 "氢系统中最高温度探针代号":"",
#                 "氢气最高浓度":"",
#                 "氢气最高浓度传感器代号":"",
#                 "氢气最高压力":"",
#                 "氢气最高压力传感器代号":"",
#                 "高压DC/DC状态":""
#             },
#             "发动机数据":{
#                 "发动机状态":"",
#                 "曲轴转速":"",
#                 "燃料消耗率":""
#             },
#             "车辆位置数据":{
#                 "定位状态":"1",
#                 "经度":"4",
#                 "纬度":"4"
#             },
#             "极值数据":{
#                 "最高电压电池子系统号":"",
#                 "最高电压电池单体代号":"",
#                 "电池单体电压最高值":"",
#                 "最低电压电池子系统号":"",
#                 "最低电压电池单体代号":"",
#                 "电池单体电压最低值":"",
#                 "最高温度子系统号":"",
#                 "最高温度探针序号":"",
#                 "最高温度值":"",
#                 "最低温度子系统号":"",
#                 "最低温度探针序号":"",
#                 "最低温度值":""
#             },
#             "报警数据":{
#                 "最高报警等级":"",
#                 "通用报警标志":"",
#                 "可充电储能装置故障总数N1":"",
#                 "可充电储能装置故障代码列表":{
#                     "1":{},
#                     "2":{}
#                 },
#                 "驱动电机故障总数N2":"",
#                 "驱动电机故障代码列表":{
#                     "1":{},
#                     "2":{}
#                 },
#                 "发动机故障总数N3":"",
#                 "发动机故障列表":{
#                     "1":{},
#                     "2":{}
#                 },
#                 "其他故障总数N4":"",
#                 "其他故障代码列表":{
#                     "1":{},
#                     "2":{}
#                 }
#             },
#             "可充电储能装置电压数据":{
#                 "可充电储能子系统个数":"",
#                 "可充电储能子系统电压信息列表":{
#                     "1":{
#                         "可充电储能装置电压":"",
#                         "可充电储能装置电流":"",
#                         "单体电池总数":"",
#                         "本帧起始电池序号":"",
#                         "本帧单体电池总数n":"",
#                         "单体电池电压":"[n*2]"
#                     },
#                     "2":{}
#                 }
#             },
#             "可充电储能装置温度数据":{
#                 "可充电储能子系统个数":"1",
#                 "可充电储能子系统温度信息列表":{
#                     "1":{
#                         "可充电储能温度探针个数":"1",
#                         "可充电储能子系统各温度探针检测到的温度值":"[n*2]"
#                     },
#                     "2":{}
#                 }
#             }
#         },
#         "车辆登出":{
#             "登出时间":"6",
#             "登出流水号":"2"
#         },
#         "平台登入":{
#             "平台登入时间":"6",
#             "登入流水号":"2",
#             "平台用户名":"",
#             "平台密码":"",
#             "加密规则":""
#         },
#         "平台登出":{
#             "登出时间":"6",
#             "登出流水号":"2"
#         }
#     },
#     "效验码":"1"
# }
# ```
