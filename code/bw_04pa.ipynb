# %%
import numpy as np
import pandas as pd
import binascii
import datetime
import math

# %%
import Ipynb_importer
from public_function import * 
from bw_01cf import *
from bw_02jx import *

# %%
# 277项
list_code = pd.read_excel("data/异常code清单.xlsx", sheet_name="Sheet2", index_col="code")
list_code["数量"] = 0
list_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7be18b962885> in <module>
#       1 # 277项
# ----> 2 list_code = pd.read_excel("data/异常code清单.xlsx", sheet_name="Sheet2", index_col="code")
#       3 list_code["数量"] = 0
#       4 list_code
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 异常报文分析

# %%
# 277项
list_code = pd.read_excel("data/异常code清单.xlsx", sheet_name="Sheet2", index_col="code")
list_code["数量"] = 0
list_code
# Out:
#                                           错误项  数量
# code
# 1                                    里程为空或者无效   0
# 2                                   档位为空值或者无效   0
# 6                                  车速大于0档位为P档   0
# 7                                   速度为空或者无效值   0
# 8                              速度大于220KM/H或无效   0
# 9                                  驱动力为空值或者无效   0
# 10                                  制动力为空值或无效   0
# 11                                 加速踏板值为空或无效   0
# 12                             加速踏板值大于100%或无效   0
# 13                                加速踏板有效驱动力无效   0
# 14                                制动踏板值为空或者无效   0
# 15                            制动踏板值大于100%或者无效   0
# 16                                制动踏板有效制动力无效   0
# 17                         驱动有效加速踏板值大于100%或无效   0
# 18                                 总电压值为空或者无效   0
# 19                              总电压大于2000V或无效   0
# 20                               单体电压列表为空或者无效   0
# 21                                单体包单体列表长度错误   0
# 22                            单体电压数据大于60V或者为0   0
# 23                            单体电压列表子系统为空或者无效   0
# 24                               总电压不等于单体电压总和   0
# 25                                  总电流值为空或无效   0
# 26                             总电流值大于2000A或无效   0
# 27                                驱动电机列表为空或无效   0
# 28                              驱动电机列表数据为空或无效   0
# 29                               驱动电机序号为空或者无效   0
# 30                               驱动电机状态为空或者无效   0
# 31                               驱动电机状态大于4或无效   0
# 32                            驱动电机控制器温度为空或者无效   0
# 33        驱动电机控制器温度大于250(210摄氏度)或无效(小于-40摄氏度)   0
# ...                                       ...  ..
# 614                          上传最低温度子系统号为异常值FE   0
# 615                          上传最低温度子系统号为无效值FF   0
# 617                               未上传最低温度探针序号   0
# 618                          上传最低温度探针序号为异常值FE   0
# 619                          上传最低温度探针序号为无效值FF   0
# 621                                  未上传最低温度值   0
# 622                             上传最低温度值为异常值FE   0
# 623                             上传最低温度值为无效值FF   0
# 624                     上传最低温度值值不在阈值[0，250]范围   0
# 628                   上传登入流水号值不在阈值[1，63331]范围   0
# 629                   上传登出流水号值不在阈值[1，63331]范围   0
# 700                                    报文时间重复   0
# 701                           多条相同时间报文车辆状态不一样   0
# 702                            多条相同时间报文里程值不一样   0
# 703                                熄火过程中里程值变化   0
# 704                            启动切换到熄火状态里程值变化   0
# 705                            熄火切换到启动状态里程值变化   0
# 711                                车辆状态非1-2-3   0
# 734                       登录报文时间与服务器时间差超过180秒   0
# 748                      实时数据时间与服务器时间相差超过180秒   0
# 1001                 实时有效数据报文条数不足(实时数据报文条数不足)   0
# 1002                                  总报文条数不足   0
# 2001                               车辆状态非1-2-3   0
# 2002                                    熄火非充电   0
# 2100                                   报文时间重复   0
# 2101      多条相同时间报文车辆状态不一样                       0
# 2102     多条相同时间报文里程值不一样                         0
# 2103  熄火过程中里程值变化                                0
# 2104     熄火切换到启动状态里程值变化                         0
# 2105                     启动切换到熄火状态里程值变化         0
#
# [277 rows x 2 columns]
